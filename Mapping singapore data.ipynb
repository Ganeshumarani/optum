# %%
import pandas as pd
import numpy as np
import os,glob

# %%
os.chdir("C:/Users/Ganesh P Umarani/Desktop/crawlers_data_as_on_15_july_2019/Singapore")

# %%
singapore=pd.read_csv("Singapore_all_files.csv")

# %%
singapore.columns
# Out:
# Index(['Device Name', 'Description', 'Medical Specialty Area',
#        'Medical Device Class', 'Device Registration No', 'Registration Date',
#        'Change Notification Approval Date', 'Device System Info',
#        'Product Owner', 'Registrant', 'Model Name', 'MI', 'Page URL'],
#       dtype='object')

# %%
singapore=singapore[singapore.MI.notnull()]

# %%
singapore.rename({'Model Identifier':'MI'},axis=1,inplace=True)

# %%
os.chdir("C:/Users/Ganesh P Umarani/Desktop/Optum/Ganesh_Merged_Files/Merged files duplicates/Unique item master files")

# %%
to_map=pd.read_csv("All_files_merged_no_dup_with_spend_new_2.csv")
# Out:
# c:\users\ganesh p umarani\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
to_map_mpn=to_map[to_map.Mfg_part_num_x.notnull()]

# %%
to_map_mpn_sk=to_map_mpn[['Secodary_key','Mfg_part_num_x']]

# %%
temp=['Device Name', 'Description', 'Medical Specialty Area',
       'Medical Device Class', 'Device Registration No','Device System Info',
       'Product Owner', 'Registrant', 'Model Name', 'MI', 'Page URL']
output_result=pd.DataFrame(columns=temp)

# %%
output_result.columns
# Out:
# Index(['Device Name', 'Description', 'Medical Specialty Area',
#        'Medical Device Class', 'Device Registration No', 'Device System Info',
#        'Product Owner', 'Registrant', 'Model Name', 'MI', 'Page URL'],
#       dtype='object')

# %%
for idx, row in to_map_mpn_sk.iterrows():
    if (row.Mfg_part_num_x not in [np.nan]):
        to_srch_main=str(row['Mfg_part_num_x']).replace(".","")
        flag=0
        
        for i in range(4):
            
            if i==0:
                to_search=str(to_srch_main).lstrip("0").replace("-","")
                output=singapore.query('MI.str.contains(@to_search)')
                if (len(output)>0):
                    flag=1
                    for f in range(len(output)):
                        output_result=output_result.append({
                                           'Device Name':output['Device Name'].get_values()[0],
                                           'Description':output['Description'].get_values()[0],
                                           'Medical Specialty Area':output['Medical Specialty Area'].get_values()[0],
                                           'Medical Device Class':output['Medical Device Class'].get_values()[0],
                                           'Device Registration No':output['Device Registration No'].get_values()[0],
                                           'Device System Info':output['Device System Info'].get_values()[0],
                                           'Product Owner':output['Product Owner'].get_values()[0],
                                           'Registrant':output['Registrant'].get_values()[0],
                                           'Model Name':output['Model Name'].get_values()[0],
                                           'MI':output['MI'].get_values()[0],
                                           'Page URL':output['Page URL'].get_values()[0],
                                           'Secodary_key':row['Secodary_key']},ignore_index=True)
                    print(to_search)
                
                            
                    
            elif (i==1 and flag==0):
                to_search=str(to_srch_main).replace("-","")
                output=singapore.query('MI.str.contains(@to_search)')
                if (len(output)>0):
                    flag=1
                    for f in range(len(output)):
                        output_result=output_result.append({
                                           'Device Name':output['Device Name'].get_values()[0],
                                           'Description':output['Description'].get_values()[0],
                                           'Medical Specialty Area':output['Medical Specialty Area'].get_values()[0],
                                           'Medical Device Class':output['Medical Device Class'].get_values()[0],
                                           'Device Registration No':output['Device Registration No'].get_values()[0],
                                           'Device System Info':output['Device System Info'].get_values()[0],
                                           'Product Owner':output['Product Owner'].get_values()[0],
                                           'Registrant':output['Registrant'].get_values()[0],
                                           'Model Name':output['Model Name'].get_values()[0],
                                           'MI':output['MI'].get_values()[0],
                                           'Page URL':output['Page URL'].get_values()[0],
                                           'Secodary_key':row['Secodary_key']},ignore_index=True)
                    print(to_search)
                        
                        
            elif (i==2and flag==0):
                to_search=str(to_srch_main).lstrip("0")
                output=singapore.query('MI.str.contains(@to_search)')
                if (len(output)>0):
                    flag=1
                    for f in range(len(output)):
                        output_result=output_result.append({
                                           'Device Name':output['Device Name'].get_values()[0],
                                           'Description':output['Description'].get_values()[0],
                                           'Medical Specialty Area':output['Medical Specialty Area'].get_values()[0],
                                           'Medical Device Class':output['Medical Device Class'].get_values()[0],
                                           'Device Registration No':output['Device Registration No'].get_values()[0],
                                           'Device System Info':output['Device System Info'].get_values()[0],
                                           'Product Owner':output['Product Owner'].get_values()[0],
                                           'Registrant':output['Registrant'].get_values()[0],
                                           'Model Name':output['Model Name'].get_values()[0],
                                           'MI':output['MI'].get_values()[0],
                                           'Page URL':output['Page URL'].get_values()[0],
                                           'Secodary_key':row['Secodary_key']},ignore_index=True)
                    print(to_search)
            
            else:
                to_search=str(to_srch_main)
                output=singapore.query('MI.str.contains(@to_search)')
                if (len(output)>0):
                    flag=1
                    for f in range(len(output)):
                        output_result=output_result.append({
                                           'Device Name':output['Device Name'].get_values()[0],
                                           'Description':output['Description'].get_values()[0],
                                           'Medical Specialty Area':output['Medical Specialty Area'].get_values()[0],
                                           'Medical Device Class':output['Medical Device Class'].get_values()[0],
                                           'Device Registration No':output['Device Registration No'].get_values()[0],
                                           'Device System Info':output['Device System Info'].get_values()[0],
                                           'Product Owner':output['Product Owner'].get_values()[0],
                                           'Registrant':output['Registrant'].get_values()[0],
                                           'Model Name':output['Model Name'].get_values()[0],
                                           'MI':output['MI'].get_values()[0],
                                           'Page URL':output['Page URL'].get_values()[0],
                                           'Secodary_key':row['Secodary_key']},ignore_index=True)
                    print(to_search)
# Out:
# c:\users\ganesh p umarani\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   from ipykernel import kernelapp as app
# c:\users\ganesh p umarani\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   app.launch_new_instance()
# c:\users\ganesh p umarani\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
# ...

# %%
output_result.to_csv("singapore_mapped.csv")

# %%
len(output_result)
# Out:
# 1142868
